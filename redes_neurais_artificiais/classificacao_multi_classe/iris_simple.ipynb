# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils

base = pd.read_csv('iris.csv')
previsores = base.iloc[:, 0:4].values
classe = base.iloc[:, 4].values

# %% [markdown]
# Formatar a classe de teste para suportar multi classes

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
classe = labelencoder.fit_transform(classe)
classe_dummy = np_utils.to_categorical(classe)

# %% [markdown]
# Usar a classe_dummy para executar o treinamento

# %%
from sklearn.model_selection import train_test_split
previsores_trainamento, previsores_teste, classe_trainamento, classe_teste = train_test_split(previsores, classe_dummy, test_size=0.25)

# %%
classificador = Sequential()
classificador.add(Dense(units = 4, activation = 'relu', input_dim = 4))
classificador.add(Dense(units = 4, activation = 'relu'))
classificador.add(Dense(units = 3, activation = 'softmax'))
classificador.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
classificador.fit(previsores_trainamento, classe_trainamento, batch_size = 10, epochs = 1000)
# Out:
# Epoch 1/1000
# 12/12 [==============================] - 1s 1ms/step - loss: 1.0799 - categorical_accuracy: 0.3304
# Epoch 2/1000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.9661 - categorical_accuracy: 0.3482
# Epoch 3/1000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8914 - categorical_accuracy: 0.5893
# Epoch 4/1000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8489 - categorical_accuracy: 0.6250
# Epoch 5/1000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8273 - categorical_accuracy: 0.6429
# Epoch 6/1000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8104 - categorical_accuracy: 0.6786
# Epoch 7/1000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7956 - categorical_accuracy: 0.7232
# Epoch 8/1000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7797 - categorical_accuracy: 0.7500
# Epoch 9/1000
# ...

# %% [markdown]
# Analise de precisao na base de treinamento

# %%
#analise do keras
resultado = classificador.evaluate(previsores_teste, classe_teste)
#analise manual
previsoes = classificador.predict(previsores_teste)
# Out:
# ...
# 2/2 [==============================] - 0s 3ms/step

# %% [markdown]
# Gerando matrix de confusao

# %%
previsoes = (previsoes > 0.5)


from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(classe_teste.argmax(axis=1), previsoes.argmax(axis=1))

# usar matrix de confusao para avaliar o modelo. eh possivel ver que o modelo acertou 37 de 38 casos.
