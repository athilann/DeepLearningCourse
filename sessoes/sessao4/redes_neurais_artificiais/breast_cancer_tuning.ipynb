# %%
import os
import keras
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
#from scikeras.wrappers import KerasClassifier, KerasRegressor
from sklearn.model_selection import GridSearchCV

os.chdir(os.getcwd())
print(os.getcwd())

previsores = pd.read_csv('entradas_breast.csv')
classe = pd.read_csv('saidas_breast.csv')
# Out:
# c:\Users\athil\source\repos\DeepLearningCourse\sessoes\sessao4\redes_neurais_artificiais

# %% [markdown]
# Funcao padrao de criacao da rede neural

# %%
def createNetwork(optimizer, loss, kernel_initializer, activation, neurons):
    classificador = Sequential()
    classificador.add(Dense(units = neurons, activation = activation, kernel_initializer = kernel_initializer, input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = neurons, activation = activation, kernel_initializer = kernel_initializer))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))

    classificador.compile(optimizer = optimizer, loss = loss , metrics = ['binary_accuracy'])
    return classificador

# %% [markdown]
# Criando rede neural

# %%
classificador = KerasClassifier(build_fn = createNetwork)
parametros = {
    'batch_size': [10, 30], 
    'epochs': [50, 100], 
    'optimizer': ['adam', 'sgd'], 
    'loss': ['binary_crossentropy', 'hinge'], 
    'kernel_initializer': ['random_uniform', 'normal'], 
    'activation': ['relu', 'tanh'], 
    'neurons': [16, 8]
    }
# Out:
# C:\Users\athil\AppData\Local\Temp\ipykernel_19544\2303022932.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   classificador = KerasClassifier(build_fn = createNetwork)

# %% [markdown]
# Executando uma Grid Search para achar a melhor configuracao de rede neural

# %%
grid_search = GridSearchCV(estimator = classificador, param_grid = parametros, scoring = 'accuracy', cv = 5)
grid_search = grid_search.fit(previsores, classe)

#melhores_parametros = grid_search.best_params_
# Out:
# Epoch 1/50
# 46/46 [==============================] - 1s 1ms/step - loss: 1.1622 - binary_accuracy: 0.5560
# Epoch 2/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6113 - binary_accuracy: 0.6505
# Epoch 3/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.5857 - binary_accuracy: 0.6066
# Epoch 4/50
# 46/46 [==============================] - 0s 1000us/step - loss: 0.5674 - binary_accuracy: 0.6418
# Epoch 5/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.5381 - binary_accuracy: 0.6440
# Epoch 6/50
# 46/46 [==============================] - 0s 1000us/step - loss: 0.5106 - binary_accuracy: 0.6791
# Epoch 7/50
# 46/46 [==============================] - 0s 1000us/step - loss: 0.5417 - binary_accuracy: 0.7143
# Epoch 8/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4849 - binary_accuracy: 0.7824
# Epoch 9/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4753 - binary_accuracy: 0.7824
# Epoch 10/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4711 - binary_accuracy: 0.8000
# Epoch 11/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4505 - binary_accuracy: 0.8066
# Epoch 12/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4344 - binary_accuracy: 0.8220
# Epoch 13/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4270 - binary_accuracy: 0.8220
# Epoch 14/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4246 - binary_accuracy: 0.8198
# Epoch 15/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4090 - binary_accuracy: 0.8308
# Epoch 16/50
# 46/46 [==============================] - 0s 1000us/step - loss: 0.3855 - binary_accuracy: 0.8505
# Epoch 17/50
# 46/46 [==============================] - 0s 1000us/step - loss: 0.3711 - binary_accuracy: 0.8462
# Epoch 18/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.4163 - binary_accuracy: 0.8374
# Epoch 19/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3874 - binary_accuracy: 0.8264
# Epoch 20/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3785 - binary_accuracy: 0.8571
# Epoch 21/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3504 - binary_accuracy: 0.8659
# Epoch 22/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.3611 - binary_accuracy: 0.8462
# Epoch 23/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.3212 - binary_accuracy: 0.8747
# Epoch 24/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3283 - binary_accuracy: 0.8835
# Epoch 25/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3077 - binary_accuracy: 0.8813
# Epoch 26/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3197 - binary_accuracy: 0.8769
# Epoch 27/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2960 - binary_accuracy: 0.8813
# Epoch 28/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3462 - binary_accuracy: 0.8747
# Epoch 29/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3216 - binary_accuracy: 0.8681
# Epoch 30/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2916 - binary_accuracy: 0.8901
# Epoch 31/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2950 - binary_accuracy: 0.8901
# Epoch 32/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3043 - binary_accuracy: 0.8857
# Epoch 33/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3145 - binary_accuracy: 0.8615
# Epoch 34/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2892 - binary_accuracy: 0.8923
# Epoch 35/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2778 - binary_accuracy: 0.8857
# Epoch 36/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3098 - binary_accuracy: 0.8791
# Epoch 37/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2815 - binary_accuracy: 0.8835
# Epoch 38/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2702 - binary_accuracy: 0.8945
# Epoch 39/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3297 - binary_accuracy: 0.8637
# Epoch 40/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2863 - binary_accuracy: 0.8901
# Epoch 41/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3003 - binary_accuracy: 0.8747
# Epoch 42/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3073 - binary_accuracy: 0.8791
# Epoch 43/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2924 - binary_accuracy: 0.8901
# Epoch 44/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3300 - binary_accuracy: 0.8659
# Epoch 45/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3139 - binary_accuracy: 0.8769
# Epoch 46/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2721 - binary_accuracy: 0.9055
# Epoch 47/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3182 - binary_accuracy: 0.8703
# Epoch 48/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3158 - binary_accuracy: 0.8659
# Epoch 49/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3099 - binary_accuracy: 0.8703
# Epoch 50/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2762 - binary_accuracy: 0.9033
# 4/4 [==============================] - 0s 1000us/step
# Epoch 1/50
# 46/46 [==============================] - 1s 1ms/step - loss: 1.7080 - binary_accuracy: 0.5341
# Epoch 2/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.7445 - binary_accuracy: 0.6308
# Epoch 3/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6295 - binary_accuracy: 0.6527
# Epoch 4/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5988 - binary_accuracy: 0.5978
# Epoch 5/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6167 - binary_accuracy: 0.6308
# Epoch 6/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.5641 - binary_accuracy: 0.6527
# Epoch 7/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.5422 - binary_accuracy: 0.6615
# Epoch 8/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.5427 - binary_accuracy: 0.6681
# Epoch 9/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.5317 - binary_accuracy: 0.6593
# Epoch 10/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.5373 - binary_accuracy: 0.6769
# Epoch 11/50
# 46/46 [==============================] - 0s 1000us/step - loss: 0.5055 - binary_accuracy: 0.7055
# Epoch 12/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4906 - binary_accuracy: 0.7033
# Epoch 13/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4929 - binary_accuracy: 0.6989
# Epoch 14/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.5055 - binary_accuracy: 0.7143
# Epoch 15/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.4781 - binary_accuracy: 0.7560
# Epoch 16/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.4442 - binary_accuracy: 0.7626
# Epoch 17/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.5171 - binary_accuracy: 0.7253
# Epoch 18/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4500 - binary_accuracy: 0.7956
# Epoch 19/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4278 - binary_accuracy: 0.7692
# Epoch 20/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.4051 - binary_accuracy: 0.8198
# Epoch 21/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.4036 - binary_accuracy: 0.7956
# Epoch 22/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3793 - binary_accuracy: 0.8440
# Epoch 23/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3693 - binary_accuracy: 0.8242
# Epoch 24/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3693 - binary_accuracy: 0.8484
# Epoch 25/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.3508 - binary_accuracy: 0.8549
# Epoch 26/50
# 46/46 [==============================] - 0s 1000us/step - loss: 0.3600 - binary_accuracy: 0.8352
# Epoch 27/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2990 - binary_accuracy: 0.8725
# Epoch 28/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.3538 - binary_accuracy: 0.8396
# Epoch 29/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.3237 - binary_accuracy: 0.8549
# Epoch 30/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.3194 - binary_accuracy: 0.8791
# Epoch 31/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2920 - binary_accuracy: 0.8945
# Epoch 32/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2797 - binary_accuracy: 0.8857
# Epoch 33/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.3025 - binary_accuracy: 0.8791
# Epoch 34/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.2898 - binary_accuracy: 0.8989
# Epoch 35/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2624 - binary_accuracy: 0.8835
# Epoch 36/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2471 - binary_accuracy: 0.9121
# Epoch 37/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2652 - binary_accuracy: 0.8835
# Epoch 38/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.2784 - binary_accuracy: 0.8967
# Epoch 39/50
# 46/46 [==============================] - 0s 1000us/step - loss: 0.2685 - binary_accuracy: 0.9055
# Epoch 40/50
# 46/46 [==============================] - 0s 933us/step - loss: 0.2618 - binary_accuracy: 0.8901
# Epoch 41/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2515 - binary_accuracy: 0.9099
# Epoch 42/50
# 46/46 [==============================] - 0s 955us/step - loss: 0.2162 - binary_accuracy: 0.9099
# Epoch 43/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2464 - binary_accuracy: 0.8857
# Epoch 44/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.2393 - binary_accuracy: 0.9121
# Epoch 45/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2260 - binary_accuracy: 0.9165
# Epoch 46/50
# 46/46 [==============================] - 0s 1000us/step - loss: 0.2090 - binary_accuracy: 0.9165
# Epoch 47/50
# 46/46 [==============================] - 0s 999us/step - loss: 0.2561 - binary_accuracy: 0.8967
# Epoch 48/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2415 - binary_accuracy: 0.8989
# Epoch 49/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2352 - binary_accuracy: 0.9121
# Epoch 50/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2304 - binary_accuracy: 0.9143
# 4/4 [==============================] - 0s 1ms/step
# Epoch 1/50
# 46/46 [==============================] - 1s 1000us/step - loss: 1.2588 - binary_accuracy: 0.5802
# Epoch 2/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6234 - binary_accuracy: 0.6462
# Epoch 3/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.6040 - binary_accuracy: 0.6440
# Epoch 4/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.5535 - binary_accuracy: 0.6659
# Epoch 5/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.5131 - binary_accuracy: 0.7187
# Epoch 6/50
# 46/46 [==============================] - 0s 1000us/step - loss: 0.5100 - binary_accuracy: 0.7209
# Epoch 7/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.5019 - binary_accuracy: 0.6967
# Epoch 8/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.5071 - binary_accuracy: 0.7341
# Epoch 9/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.4566 - binary_accuracy: 0.7582
# Epoch 10/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.4681 - binary_accuracy: 0.7385
# Epoch 11/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.4609 - binary_accuracy: 0.7890
# Epoch 12/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.4313 - binary_accuracy: 0.8088
# Epoch 13/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.4335 - binary_accuracy: 0.8044
# Epoch 14/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4172 - binary_accuracy: 0.8022
# Epoch 15/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4403 - binary_accuracy: 0.8022
# Epoch 16/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4113 - binary_accuracy: 0.8418
# Epoch 17/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3511 - binary_accuracy: 0.8615
# Epoch 18/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3626 - binary_accuracy: 0.8769
# Epoch 19/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3693 - binary_accuracy: 0.8242
# Epoch 20/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3531 - binary_accuracy: 0.8418
# Epoch 21/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3298 - binary_accuracy: 0.8813
# Epoch 22/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3211 - binary_accuracy: 0.8835
# Epoch 23/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3036 - binary_accuracy: 0.9033
# Epoch 24/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3093 - binary_accuracy: 0.8769
# Epoch 25/50
# 46/46 [==============================] - 0s 1000us/step - loss: 0.2863 - binary_accuracy: 0.9011
# Epoch 26/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.2873 - binary_accuracy: 0.8989
# Epoch 27/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2635 - binary_accuracy: 0.8923
# Epoch 28/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.2864 - binary_accuracy: 0.8857
# Epoch 29/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.2860 - binary_accuracy: 0.8835
# Epoch 30/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.2858 - binary_accuracy: 0.8879
# Epoch 31/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.2887 - binary_accuracy: 0.8835
# Epoch 32/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3301 - binary_accuracy: 0.8527
# Epoch 33/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2956 - binary_accuracy: 0.8681
# Epoch 34/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2658 - binary_accuracy: 0.8879
# Epoch 35/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2373 - binary_accuracy: 0.8967
# Epoch 36/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2703 - binary_accuracy: 0.8857
# Epoch 37/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2295 - binary_accuracy: 0.9143
# Epoch 38/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.2834 - binary_accuracy: 0.8835
# Epoch 39/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.2533 - binary_accuracy: 0.9011
# Epoch 40/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2422 - binary_accuracy: 0.9077
# Epoch 41/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2689 - binary_accuracy: 0.8923
# Epoch 42/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2283 - binary_accuracy: 0.8967
# Epoch 43/50
# 46/46 [==============================] - 0s 1000us/step - loss: 0.2198 - binary_accuracy: 0.9187
# Epoch 44/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.2624 - binary_accuracy: 0.8879
# Epoch 45/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2311 - binary_accuracy: 0.9165
# Epoch 46/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2377 - binary_accuracy: 0.9033
# Epoch 47/50
# 46/46 [==============================] - 0s 1000us/step - loss: 0.2355 - binary_accuracy: 0.9099
# Epoch 48/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2577 - binary_accuracy: 0.9077
# Epoch 49/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.2196 - binary_accuracy: 0.9055
# Epoch 50/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2440 - binary_accuracy: 0.9121
# 4/4 [==============================] - 0s 1ms/step
# Epoch 1/50
# 46/46 [==============================] - 1s 1ms/step - loss: 1.6939 - binary_accuracy: 0.5429
# Epoch 2/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6043 - binary_accuracy: 0.6198
# Epoch 3/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.5351 - binary_accuracy: 0.6462
# Epoch 4/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.5390 - binary_accuracy: 0.6791
# Epoch 5/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.5383 - binary_accuracy: 0.6703
# Epoch 6/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.5151 - binary_accuracy: 0.6505
# Epoch 7/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4982 - binary_accuracy: 0.7187
# Epoch 8/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4840 - binary_accuracy: 0.6989
# Epoch 9/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.4971 - binary_accuracy: 0.7275
# Epoch 10/50
# 46/46 [==============================] - 0s 933us/step - loss: 0.4841 - binary_accuracy: 0.7516
# Epoch 11/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.4500 - binary_accuracy: 0.7736
# Epoch 12/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.4229 - binary_accuracy: 0.7912
# Epoch 13/50
# 46/46 [==============================] - 0s 933us/step - loss: 0.3914 - binary_accuracy: 0.8440
# Epoch 14/50
# 46/46 [==============================] - 0s 889us/step - loss: 0.3926 - binary_accuracy: 0.8022
# Epoch 15/50
# 46/46 [==============================] - 0s 889us/step - loss: 0.3909 - binary_accuracy: 0.8374
# Epoch 16/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.3623 - binary_accuracy: 0.8505
# Epoch 17/50
# 46/46 [==============================] - 0s 933us/step - loss: 0.3576 - binary_accuracy: 0.8615
# Epoch 18/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.3510 - binary_accuracy: 0.8637
# Epoch 19/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.3460 - binary_accuracy: 0.8681
# Epoch 20/50
# 46/46 [==============================] - 0s 933us/step - loss: 0.3269 - binary_accuracy: 0.8791
# Epoch 21/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.3261 - binary_accuracy: 0.8747
# Epoch 22/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.3268 - binary_accuracy: 0.8659
# Epoch 23/50
# 46/46 [==============================] - 0s 889us/step - loss: 0.3201 - binary_accuracy: 0.8835
# Epoch 24/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.3046 - binary_accuracy: 0.8747
# Epoch 25/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.3302 - binary_accuracy: 0.8725
# Epoch 26/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.3631 - binary_accuracy: 0.8374
# Epoch 27/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.3288 - binary_accuracy: 0.8681
# Epoch 28/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2922 - binary_accuracy: 0.8923
# Epoch 29/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.3014 - binary_accuracy: 0.8813
# Epoch 30/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2813 - binary_accuracy: 0.8857
# Epoch 31/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.2891 - binary_accuracy: 0.8791
# Epoch 32/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.2687 - binary_accuracy: 0.9011
# Epoch 33/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2706 - binary_accuracy: 0.9011
# Epoch 34/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3074 - binary_accuracy: 0.8813
# Epoch 35/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.2856 - binary_accuracy: 0.8945
# Epoch 36/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2461 - binary_accuracy: 0.9033
# Epoch 37/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.2619 - binary_accuracy: 0.8945
# Epoch 38/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2524 - binary_accuracy: 0.8879
# Epoch 39/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2372 - binary_accuracy: 0.9099
# Epoch 40/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2550 - binary_accuracy: 0.8945
# Epoch 41/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2456 - binary_accuracy: 0.8923
# Epoch 42/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2168 - binary_accuracy: 0.9187
# Epoch 43/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2228 - binary_accuracy: 0.9165
# Epoch 44/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2352 - binary_accuracy: 0.9055
# Epoch 45/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2459 - binary_accuracy: 0.8945
# Epoch 46/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2290 - binary_accuracy: 0.9099
# Epoch 47/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2320 - binary_accuracy: 0.9165
# Epoch 48/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2465 - binary_accuracy: 0.9033
# Epoch 49/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.3106 - binary_accuracy: 0.8615
# Epoch 50/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2348 - binary_accuracy: 0.8945
# 4/4 [==============================] - 0s 1ms/step
# Epoch 1/50
# 46/46 [==============================] - 1s 978us/step - loss: 1.5218 - binary_accuracy: 0.5592
# Epoch 2/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.6792 - binary_accuracy: 0.5943
# Epoch 3/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.5839 - binary_accuracy: 0.6338
# Epoch 4/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6025 - binary_accuracy: 0.6053
# Epoch 5/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.5523 - binary_accuracy: 0.6469
# Epoch 6/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.5736 - binary_accuracy: 0.6667
# Epoch 7/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5242 - binary_accuracy: 0.6886
# Epoch 8/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.5099 - binary_accuracy: 0.6930
# Epoch 9/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.5317 - binary_accuracy: 0.6820
# Epoch 10/50
# 46/46 [==============================] - 0s 889us/step - loss: 0.5238 - binary_accuracy: 0.6842
# Epoch 11/50
# 46/46 [==============================] - 0s 889us/step - loss: 0.5096 - binary_accuracy: 0.7039
# Epoch 12/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4895 - binary_accuracy: 0.7259
# Epoch 13/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4831 - binary_accuracy: 0.7500
# Epoch 14/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.4482 - binary_accuracy: 0.7719
# Epoch 15/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.4664 - binary_accuracy: 0.7456
# Epoch 16/50
# 46/46 [==============================] - 0s 1000us/step - loss: 0.4584 - binary_accuracy: 0.7982
# Epoch 17/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4252 - binary_accuracy: 0.8004
# Epoch 18/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.3995 - binary_accuracy: 0.8487
# Epoch 19/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.3979 - binary_accuracy: 0.8180
# Epoch 20/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.3889 - binary_accuracy: 0.8246
# Epoch 21/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.3897 - binary_accuracy: 0.8377
# Epoch 22/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3648 - binary_accuracy: 0.8421
# Epoch 23/50
# 46/46 [==============================] - 0s 955us/step - loss: 0.3833 - binary_accuracy: 0.8246
# Epoch 24/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.3633 - binary_accuracy: 0.8728
# Epoch 25/50
# 46/46 [==============================] - 0s 1000us/step - loss: 0.3444 - binary_accuracy: 0.8509
# Epoch 26/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3373 - binary_accuracy: 0.8684
# Epoch 27/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3377 - binary_accuracy: 0.8575
# Epoch 28/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3041 - binary_accuracy: 0.8684
# Epoch 29/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3054 - binary_accuracy: 0.8750
# Epoch 30/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3188 - binary_accuracy: 0.8640
# Epoch 31/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2988 - binary_accuracy: 0.8706
# Epoch 32/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2693 - binary_accuracy: 0.9057
# Epoch 33/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2562 - binary_accuracy: 0.9035
# Epoch 34/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2824 - binary_accuracy: 0.8860
# Epoch 35/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2713 - binary_accuracy: 0.8882
# Epoch 36/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2564 - binary_accuracy: 0.8991
# Epoch 37/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2707 - binary_accuracy: 0.8991
# Epoch 38/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2773 - binary_accuracy: 0.8838
# Epoch 39/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2650 - binary_accuracy: 0.8904
# Epoch 40/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2526 - binary_accuracy: 0.9013
# Epoch 41/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2474 - binary_accuracy: 0.8969
# Epoch 42/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2449 - binary_accuracy: 0.8969
# Epoch 43/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.2439 - binary_accuracy: 0.9101
# Epoch 44/50
# 46/46 [==============================] - 0s 1000us/step - loss: 0.2399 - binary_accuracy: 0.8947
# Epoch 45/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.2817 - binary_accuracy: 0.8816
# Epoch 46/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.2411 - binary_accuracy: 0.8991
# Epoch 47/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2508 - binary_accuracy: 0.8991
# Epoch 48/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2074 - binary_accuracy: 0.9211
# Epoch 49/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2471 - binary_accuracy: 0.8991
# Epoch 50/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2202 - binary_accuracy: 0.9101
# 4/4 [==============================] - 0s 1000us/step
# Epoch 1/50
# 46/46 [==============================] - 1s 1000us/step - loss: 2.7089 - binary_accuracy: 0.6484
# Epoch 2/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.6975 - binary_accuracy: 0.6813
# Epoch 3/50
# 46/46 [==============================] - 0s 933us/step - loss: 0.6538 - binary_accuracy: 0.6835
# Epoch 4/50
# 46/46 [==============================] - 0s 933us/step - loss: 0.6471 - binary_accuracy: 0.6835
# Epoch 5/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.6413 - binary_accuracy: 0.6835
# Epoch 6/50
# 46/46 [==============================] - 0s 933us/step - loss: 0.6366 - binary_accuracy: 0.6835
# Epoch 7/50
# 46/46 [==============================] - 0s 978us/step - loss: 0.6348 - binary_accuracy: 0.6835
# Epoch 8/50
# 46/46 [==============================] - 0s 933us/step - loss: 0.6324 - binary_accuracy: 0.6835
# Epoch 9/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.6297 - binary_accuracy: 0.6835
# Epoch 10/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.6317 - binary_accuracy: 0.6835
# Epoch 11/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.6350 - binary_accuracy: 0.6835
# Epoch 12/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6296 - binary_accuracy: 0.6835
# Epoch 13/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6289 - binary_accuracy: 0.6835
# Epoch 14/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6293 - binary_accuracy: 0.6835
# Epoch 15/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6280 - binary_accuracy: 0.6835
# Epoch 16/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6312 - binary_accuracy: 0.6835
# Epoch 17/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6286 - binary_accuracy: 0.6835
# Epoch 18/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6287 - binary_accuracy: 0.6835
# Epoch 19/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6312 - binary_accuracy: 0.6813
# Epoch 20/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6304 - binary_accuracy: 0.6835
# Epoch 21/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6276 - binary_accuracy: 0.6835
# Epoch 22/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6286 - binary_accuracy: 0.6835
# Epoch 23/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6261 - binary_accuracy: 0.6835
# Epoch 24/50
# 46/46 [==============================] - 0s 956us/step - loss: 0.6224 - binary_accuracy: 0.6835
# Epoch 25/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.6210 - binary_accuracy: 0.6835
# Epoch 26/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.6220 - binary_accuracy: 0.6835
# Epoch 27/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.6224 - binary_accuracy: 0.6835
# Epoch 28/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.6212 - binary_accuracy: 0.6835
# Epoch 29/50
# 46/46 [==============================] - 0s 911us/step - loss: 0.6206 - binary_accuracy: 0.6835
# Epoch 30/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6405 - binary_accuracy: 0.6813
# Epoch 31/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6283 - binary_accuracy: 0.6835
# Epoch 32/50
# 46/46 [==============================] - 0s 955us/step - loss: 0.6273 - binary_accuracy: 0.6835
# Epoch 33/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6260 - binary_accuracy: 0.6835
# Epoch 34/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6272 - binary_accuracy: 0.6835
# Epoch 35/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6256 - binary_accuracy: 0.6835
# Epoch 36/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6270 - binary_accuracy: 0.6835
# Epoch 37/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6263 - binary_accuracy: 0.6835
# Epoch 38/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6248 - binary_accuracy: 0.6835
# Epoch 39/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6380 - binary_accuracy: 0.6813
# Epoch 40/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6260 - binary_accuracy: 0.6835
# Epoch 41/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6269 - binary_accuracy: 0.6835
# Epoch 42/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6253 - binary_accuracy: 0.6835
# Epoch 43/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6250 - binary_accuracy: 0.6835
# Epoch 44/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6268 - binary_accuracy: 0.6835
# Epoch 45/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6263 - binary_accuracy: 0.6835
# Epoch 46/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6264 - binary_accuracy: 0.6835
# Epoch 47/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6265 - binary_accuracy: 0.6835
# Epoch 48/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6242 - binary_accuracy: 0.6835
# Epoch 49/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6267 - binary_accuracy: 0.6835
# Epoch 50/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6245 - binary_accuracy: 0.6835
# 4/4 [==============================] - 0s 1ms/step
# Epoch 1/50
# 46/46 [==============================] - 1s 1ms/step - loss: 10.3337 - binary_accuracy: 0.6264
# Epoch 2/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6191 - binary_accuracy: 0.6418
# Epoch 3/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6181 - binary_accuracy: 0.6418
# Epoch 4/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6172 - binary_accuracy: 0.6418
# Epoch 5/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6114 - binary_accuracy: 0.6418
# Epoch 6/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6107 - binary_accuracy: 0.6418
# Epoch 7/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6157 - binary_accuracy: 0.6418
# Epoch 8/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6078 - binary_accuracy: 0.6418
# Epoch 9/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6060 - binary_accuracy: 0.6418
# Epoch 10/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6073 - binary_accuracy: 0.6418
# Epoch 11/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6030 - binary_accuracy: 0.6418
# Epoch 12/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6023 - binary_accuracy: 0.6418
# Epoch 13/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6013 - binary_accuracy: 0.6418
# Epoch 14/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6032 - binary_accuracy: 0.6418
# Epoch 15/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6036 - binary_accuracy: 0.6418
# Epoch 16/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6044 - binary_accuracy: 0.6418
# Epoch 17/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6035 - binary_accuracy: 0.6418
# Epoch 18/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6038 - binary_accuracy: 0.6418
# Epoch 19/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6020 - binary_accuracy: 0.6418
# Epoch 20/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6030 - binary_accuracy: 0.6418
# Epoch 21/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6027 - binary_accuracy: 0.6418
# Epoch 22/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6016 - binary_accuracy: 0.6418
# Epoch 23/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6020 - binary_accuracy: 0.6418
# Epoch 24/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6021 - binary_accuracy: 0.6418
# Epoch 25/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6013 - binary_accuracy: 0.6418
# Epoch 26/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6047 - binary_accuracy: 0.6418
# Epoch 27/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6055 - binary_accuracy: 0.6418
# Epoch 28/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6040 - binary_accuracy: 0.6418
# Epoch 29/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6009 - binary_accuracy: 0.6418
# Epoch 30/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6015 - binary_accuracy: 0.6418
# Epoch 31/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6024 - binary_accuracy: 0.6418
# Epoch 32/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6021 - binary_accuracy: 0.6418
# Epoch 33/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6036 - binary_accuracy: 0.6418
# Epoch 34/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6011 - binary_accuracy: 0.6418
# Epoch 35/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6020 - binary_accuracy: 0.6418
# Epoch 36/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6028 - binary_accuracy: 0.6418
# Epoch 37/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6034 - binary_accuracy: 0.6418
# Epoch 38/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6025 - binary_accuracy: 0.6418
# Epoch 39/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6020 - binary_accuracy: 0.6418
# Epoch 40/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6019 - binary_accuracy: 0.6418
# Epoch 41/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6029 - binary_accuracy: 0.6418
# Epoch 42/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6025 - binary_accuracy: 0.6418
# Epoch 43/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6013 - binary_accuracy: 0.6418
# Epoch 44/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6027 - binary_accuracy: 0.6418
# Epoch 45/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6013 - binary_accuracy: 0.6418
# Epoch 46/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6029 - binary_accuracy: 0.6418
# Epoch 47/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6018 - binary_accuracy: 0.6418
# Epoch 48/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6019 - binary_accuracy: 0.6418
# Epoch 49/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6023 - binary_accuracy: 0.6418
# Epoch 50/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6019 - binary_accuracy: 0.6418
# 4/4 [==============================] - 0s 1ms/step
# Epoch 1/50
# 46/46 [==============================] - 1s 1ms/step - loss: 4550.7974 - binary_accuracy: 0.5912
# Epoch 2/50
# 46/46 [==============================] - 0s 2ms/step - loss: 4.8123 - binary_accuracy: 0.6176
# Epoch 3/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6781 - binary_accuracy: 0.6220
# Epoch 4/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6744 - binary_accuracy: 0.6220
# Epoch 5/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6728 - binary_accuracy: 0.6220
# Epoch 6/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6693 - binary_accuracy: 0.6220
# Epoch 7/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6672 - binary_accuracy: 0.6220
# Epoch 8/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6659 - binary_accuracy: 0.6220
# Epoch 9/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6663 - binary_accuracy: 0.6220
# Epoch 10/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6643 - binary_accuracy: 0.6220
# Epoch 11/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6638 - binary_accuracy: 0.6220
# Epoch 12/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6628 - binary_accuracy: 0.6220
# Epoch 13/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6629 - binary_accuracy: 0.6220
# Epoch 14/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6626 - binary_accuracy: 0.6220
# Epoch 15/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6619 - binary_accuracy: 0.6220
# Epoch 16/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6620 - binary_accuracy: 0.6220
# Epoch 17/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6616 - binary_accuracy: 0.6220
# Epoch 18/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6622 - binary_accuracy: 0.6220
# Epoch 19/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6625 - binary_accuracy: 0.6220
# Epoch 20/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6616 - binary_accuracy: 0.6220
# Epoch 21/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6633 - binary_accuracy: 0.6220
# Epoch 22/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6610 - binary_accuracy: 0.6220
# Epoch 23/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6616 - binary_accuracy: 0.6220
# Epoch 24/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6624 - binary_accuracy: 0.6220
# Epoch 25/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6625 - binary_accuracy: 0.6220
# Epoch 26/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6608 - binary_accuracy: 0.6220
# Epoch 27/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6618 - binary_accuracy: 0.6220
# Epoch 28/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6631 - binary_accuracy: 0.6220
# Epoch 29/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6618 - binary_accuracy: 0.6220
# Epoch 30/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6622 - binary_accuracy: 0.6220
# Epoch 31/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6615 - binary_accuracy: 0.6220
# Epoch 32/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6618 - binary_accuracy: 0.6220
# Epoch 33/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6624 - binary_accuracy: 0.6220
# Epoch 34/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6620 - binary_accuracy: 0.6220
# Epoch 35/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6612 - binary_accuracy: 0.6220
# Epoch 36/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6610 - binary_accuracy: 0.6220
# Epoch 37/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6608 - binary_accuracy: 0.6220
# Epoch 38/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6619 - binary_accuracy: 0.6220
# Epoch 39/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6614 - binary_accuracy: 0.6220
# Epoch 40/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6623 - binary_accuracy: 0.6220
# Epoch 41/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6619 - binary_accuracy: 0.6220
# Epoch 42/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6609 - binary_accuracy: 0.6220
# Epoch 43/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6613 - binary_accuracy: 0.6220
# Epoch 44/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6606 - binary_accuracy: 0.6220
# Epoch 45/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6625 - binary_accuracy: 0.6220
# Epoch 46/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6611 - binary_accuracy: 0.6220
# Epoch 47/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6622 - binary_accuracy: 0.6220
# Epoch 48/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6617 - binary_accuracy: 0.6220
# Epoch 49/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6612 - binary_accuracy: 0.6220
# Epoch 50/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6608 - binary_accuracy: 0.6220
# 4/4 [==============================] - 0s 1ms/step
# Epoch 1/50
# 46/46 [==============================] - 1s 1ms/step - loss: 3.2070 - binary_accuracy: 0.5758
# Epoch 2/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6291 - binary_accuracy: 0.5978
# Epoch 3/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6252 - binary_accuracy: 0.5978
# Epoch 4/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6614 - binary_accuracy: 0.5978
# Epoch 5/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6235 - binary_accuracy: 0.5956
# Epoch 6/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6211 - binary_accuracy: 0.5978
# Epoch 7/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6194 - binary_accuracy: 0.5978
# Epoch 8/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6150 - binary_accuracy: 0.5978
# Epoch 9/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6148 - binary_accuracy: 0.5978
# Epoch 10/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6188 - binary_accuracy: 0.5978
# Epoch 11/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6244 - binary_accuracy: 0.5978
# Epoch 12/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6187 - binary_accuracy: 0.5978
# Epoch 13/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6241 - binary_accuracy: 0.5978
# Epoch 14/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6226 - binary_accuracy: 0.5978
# Epoch 15/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6197 - binary_accuracy: 0.5978
# Epoch 16/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6170 - binary_accuracy: 0.5978
# Epoch 17/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6197 - binary_accuracy: 0.5978
# Epoch 18/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6196 - binary_accuracy: 0.5978
# Epoch 19/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6170 - binary_accuracy: 0.5978
# Epoch 20/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6214 - binary_accuracy: 0.5978
# Epoch 21/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6143 - binary_accuracy: 0.5978
# Epoch 22/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6156 - binary_accuracy: 0.5978
# Epoch 23/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6151 - binary_accuracy: 0.5978
# Epoch 24/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6156 - binary_accuracy: 0.5978
# Epoch 25/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6169 - binary_accuracy: 0.5978
# Epoch 26/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6209 - binary_accuracy: 0.5978
# Epoch 27/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6209 - binary_accuracy: 0.5978
# Epoch 28/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6182 - binary_accuracy: 0.5978
# Epoch 29/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6195 - binary_accuracy: 0.5978
# Epoch 30/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6195 - binary_accuracy: 0.5978
# Epoch 31/50
# 46/46 [==============================] - 0s 914us/step - loss: 0.6169 - binary_accuracy: 0.5978
# Epoch 32/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6195 - binary_accuracy: 0.5978
# Epoch 33/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6221 - binary_accuracy: 0.5978
# Epoch 34/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6170 - binary_accuracy: 0.5978
# Epoch 35/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6195 - binary_accuracy: 0.5978
# Epoch 36/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6195 - binary_accuracy: 0.5978
# Epoch 37/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6182 - binary_accuracy: 0.5978
# Epoch 38/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6221 - binary_accuracy: 0.5978
# Epoch 39/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6208 - binary_accuracy: 0.5978
# Epoch 40/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6156 - binary_accuracy: 0.5978
# Epoch 41/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6182 - binary_accuracy: 0.5978
# Epoch 42/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6182 - binary_accuracy: 0.5978
# Epoch 43/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6195 - binary_accuracy: 0.5978
# Epoch 44/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6182 - binary_accuracy: 0.5978
# Epoch 45/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6299 - binary_accuracy: 0.5978
# Epoch 46/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6182 - binary_accuracy: 0.5978
# Epoch 47/50
# ...
# Epoch 30/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3892 - binary_accuracy: 0.8136
# Epoch 31/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3858 - binary_accuracy: 0.8026
# Epoch 32/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3732 - binary_accuracy: 0.8246
# Epoch 33/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3490 - binary_accuracy: 0.8136
# Epoch 34/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3826 - binary_accuracy: 0.8158
# Epoch 35/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3640 - binary_accuracy: 0.8092
# Epoch 36/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3843 - binary_accuracy: 0.8070
# Epoch 37/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3675 - binary_accuracy: 0.8180
# Epoch 38/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3451 - binary_accuracy: 0.8289
# Epoch 39/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3414 - binary_accuracy: 0.8180
# Epoch 40/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3150 - binary_accuracy: 0.8246
# Epoch 41/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3642 - binary_accuracy: 0.8202
# Epoch 42/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3320 - binary_accuracy: 0.8289
# Epoch 43/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3446 - binary_accuracy: 0.8092
# Epoch 44/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3266 - binary_accuracy: 0.8377
# Epoch 45/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3386 - binary_accuracy: 0.8136
# Epoch 46/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3075 - binary_accuracy: 0.8443
# Epoch 47/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3454 - binary_accuracy: 0.8246
# Epoch 48/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3119 - binary_accuracy: 0.8465
# Epoch 49/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2935 - binary_accuracy: 0.8596
# Epoch 50/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3286 - binary_accuracy: 0.8246
# 4/4 [==============================] - 0s 1000us/step
# Epoch 1/50
# 46/46 [==============================] - 1s 1ms/step - loss: 1.6994 - binary_accuracy: 0.6637
# Epoch 2/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6349 - binary_accuracy: 0.6835
# Epoch 3/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6195 - binary_accuracy: 0.6835
# Epoch 4/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6845 - binary_accuracy: 0.6813
# Epoch 5/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6156 - binary_accuracy: 0.6835
# Epoch 6/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6069 - binary_accuracy: 0.6835
# Epoch 7/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6059 - binary_accuracy: 0.6835
# Epoch 8/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6035 - binary_accuracy: 0.6835
# Epoch 9/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6038 - binary_accuracy: 0.6835
# Epoch 10/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6066 - binary_accuracy: 0.6835
# Epoch 11/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.5981 - binary_accuracy: 0.6835
# Epoch 12/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6061 - binary_accuracy: 0.6835
# Epoch 13/50
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6093 - binary_accuracy: 0.6835
# Epoch 14/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6099 - binary_accuracy: 0.6835
# Epoch 15/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6039 - binary_accuracy: 0.6835
# Epoch 16/50
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6048 - binary_accuracy: 0.6835
# Epoch 17/50
# 23/46 [==============>...............] - ETA: 0s - loss: 0.6106 - binary_accuracy: 0.6826
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 grid_search = GridSearchCV(estimator = classificador, param_grid = parametros, scoring = 'accuracy', cv = 5)
# ----> 2 grid_search = grid_search.fit(previsores, classe)
#
# File c:\Users\athil\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\athil\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\athil\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File c:\Users\athil\anaconda3\lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File c:\Users\athil\anaconda3\lib\site-packages\joblib\parallel.py:1051, in Parallel.__call__(self, iterable)
#    1048 if self.dispatch_one_batch(iterator):
#    1049     self._iterating = self._original_iterator is not None
# -> 1051 while self.dispatch_one_batch(iterator):
#    1052     pass
#    1054 if pre_dispatch == "all" or n_jobs == 1:
#    1055     # The iterable was consumed all at once by the above for loop.
#    1056     # No need to wait for async callbacks to trigger to
#    1057     # consumption.
#
# File c:\Users\athil\anaconda3\lib\site-packages\joblib\parallel.py:864, in Parallel.dispatch_one_batch(self, iterator)
#     862     return False
#     863 else:
# --> 864     self._dispatch(tasks)
#     865     return True
#
# File c:\Users\athil\anaconda3\lib\site-packages\joblib\parallel.py:782, in Parallel._dispatch(self, batch)
#     780 with self._lock:
#     781     job_idx = len(self._jobs)
# --> 782     job = self._backend.apply_async(batch, callback=cb)
#     783     # A job can complete so quickly than its callback is
#     784     # called before we get here, causing self._jobs to
#     785     # grow. To ensure correct results ordering, .insert is
#     786     # used (rather than .append) in the following line
#     787     self._jobs.insert(job_idx, job)
#
# File c:\Users\athil\anaconda3\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\athil\anaconda3\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File c:\Users\athil\anaconda3\lib\site-packages\joblib\parallel.py:263, in BatchedCalls.__call__(self)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File c:\Users\athil\anaconda3\lib\site-packages\joblib\parallel.py:263, in <listcomp>(.0)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File c:\Users\athil\anaconda3\lib\site-packages\sklearn\utils\parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File c:\Users\athil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File c:\Users\athil\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py:248, in KerasClassifier.fit(self, x, y, **kwargs)
#     246     raise ValueError("Invalid shape for y: " + str(y.shape))
#     247 self.n_classes_ = len(self.classes_)
# --> 248 return super().fit(x, y, **kwargs)
#
# File c:\Users\athil\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py:175, in BaseWrapper.fit(self, x, y, **kwargs)
#     172 fit_args = copy.deepcopy(self.filter_sk_params(Sequential.fit))
#     173 fit_args.update(kwargs)
# --> 175 history = self.model.fit(x, y, **fit_args)
#     177 return history
#
# File c:\Users\athil\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\athil\anaconda3\lib\site-packages\keras\engine\training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File c:\Users\athil\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\athil\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\athil\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:926, in Function._call(self, *args, **kwds)
#     923   self._lock.release()
#     924   # In this case we have created variables on the first call, so we run the
#     925   # defunned version which is guaranteed to never create variables.
# --> 926   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927 elif self._variable_creation_fn is not None:
#     928   # Release the lock early so that multiple threads can perform the call
#     929   # in parallel.
#     930   self._lock.release()
#
# File c:\Users\athil\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File c:\Users\athil\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\athil\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File c:\Users\athil\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:
